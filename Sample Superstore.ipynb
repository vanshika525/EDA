# %%
import pandas as pd #importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel("C:\\Users\\WELCOME\\OneDrive\\Documents\\Sample - Superstore.xls")
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
del df['Row ID']
del df['Order ID']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Row ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df
# Out:
#      Order Date  Ship Date       Ship Mode Customer ID     Customer Name  \
# 0    2016-11-08 2016-11-11    Second Class    CG-12520       Claire Gute
# 1    2016-11-08 2016-11-11    Second Class    CG-12520       Claire Gute
# 2    2016-06-12 2016-06-16    Second Class    DV-13045   Darrin Van Huff
# 3    2015-10-11 2015-10-18  Standard Class    SO-20335    Sean O'Donnell
# 4    2015-10-11 2015-10-18  Standard Class    SO-20335    Sean O'Donnell
# ...         ...        ...             ...         ...               ...
# 9989 2014-01-21 2014-01-23    Second Class    TB-21400  Tom Boeckenhauer
# 9990 2017-02-26 2017-03-03  Standard Class    DB-13060       Dave Brooks
# 9991 2017-02-26 2017-03-03  Standard Class    DB-13060       Dave Brooks
# 9992 2017-02-26 2017-03-03  Standard Class    DB-13060       Dave Brooks
# 9993 2017-05-04 2017-05-09    Second Class    CC-12220      Chris Cortes
#
#         Segment        Country             City       State  Postal Code  \
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.info() #it gives information of datatype and non-null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Date     9994 non-null   datetime64[ns]
#  1   Ship Date      9994 non-null   datetime64[ns]
#  2   Ship Mode      9994 non-null   object
#  3   Customer ID    9994 non-null   object
#  4   Customer Name  9994 non-null   object
#  5   Segment        9994 non-null   object
#  6   Country        9994 non-null   object
#  7   City           9994 non-null   object
#  8   State          9994 non-null   object
#  9   Postal Code    9994 non-null   int64
#  10  Region         9994 non-null   object
#  11  Product ID     9994 non-null   object
#  12  Category       9994 non-null   object
#  13  Sub-Category   9994 non-null   object
#  14  Product Name   9994 non-null   object
#  15  Sales          9994 non-null   float64
#  16  Quantity       9994 non-null   int64
# ...

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['State'].nunique()
# Out:
# 49

# %%
df['City'].nunique()
# Out:
# 531

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %% [markdown]
# # Analysing the sales based on category

# %%
pd.DataFrame(df.groupby(['Category'])['Sales'].mean())
# Out:
#                       Sales
# Category
# Furniture        349.834887
# Office Supplies  119.324101
# Technology       452.709276

# %% [markdown]
# # splitting the data category wise

# %%
furniture=df[df['Category']=='Furniture']
tech=df[df['Category']=='Technology']
office=df[df['Category']=='Office Supplies']

# %%
plt.bar(furniture['Category'],furniture['Sales'])
plt.bar(tech['Category'],tech['Sales'])
plt.bar(office['Category'],office['Sales'])
plt.grid()

# %% [markdown]
# # ANALYSING THE PROFIT OF DIFFERENT CATEGORIES

# %%
pd.DataFrame(df.groupby(['Category'])['Profit'].mean())
# Out:
#                     Profit
# Category
# Furniture         8.699327
# Office Supplies  20.327050
# Technology       78.752002

# %%
plt.bar(furniture['Category'],furniture['Profit'])
plt.bar(tech['Category'],tech['Profit'])
plt.bar(office['Category'],office['Profit'])
plt.grid()

# %% [markdown]
# # ANALYSING DATA BASED ON REGION

# %%
pd.DataFrame(df.groupby(['Region'])['Sales'].mean())
# Out:
#               Sales
# Region
# Central  215.772661
# East     238.336110
# South    241.803645
# West     226.493233

# %%
plt.bar(df['Region'],df['Sales'])
plt.grid()
plt.show()

# %%
plt.bar(df['Region'],df['Profit'])
plt.grid()
plt.show()

# %% [markdown]
# # SPLITTING DATA REGION WISE

# %%
south=df[df['Region']=='South']
west=df[df['Region']=='West']
east=df[df['Region']=='East']
central=df[df['Region']=='Central']

# %% [markdown]
# # COMPARING PROFITS

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
plt.title('South')
plt.bar(south['Category'],south['Profit'])
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.grid()

plt.subplot(2,2,2)
plt.title('West')
plt.bar(west['Category'],west['Profit'])
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.grid()

plt.subplot(2,2,3)
plt.title('East')
plt.bar(east['Category'],east['Profit'])
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.grid()

plt.subplot(2,2,4)
plt.title('Central')
plt.bar(central['Category'],central['Profit'])
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.grid()

plt.show()

# %% [markdown]
# # ANALYSING SALES OF DIFFERENT SEGMENTS

# %%
pd.DataFrame(df.groupby(['Segment'])['Sales'].mean())
# Out:
#                   Sales
# Segment
# Consumer     223.733644
# Corporate    233.823300
# Home Office  240.972041

# %%
plt.bar(df['Segment'],df['Sales'])
plt.grid()
plt.show()

# %% [markdown]
# # COMPARING PROFITS

# %%
pd.DataFrame(df.groupby(['Segment'])['Profit'].mean())
# Out:
#                 Profit
# Segment
# Consumer     25.836873
# Corporate    30.456667
# Home Office  33.818664

# %%
plt.bar(df['Segment'],df['Profit'])
plt.grid()
plt.show()

# %% [markdown]
# # SPLITTING CATEGORIES INTO SUBCATEGORIES

# %% [markdown]
# ## FURNITURE

# %%
bookcases=furniture[furniture['Sub-Category']=='Bookcase'][['Sub-Category','Sales','Profit']]
chairs=furniture[furniture['Sub-Category']=='Chairs'][['Sub-Category','Sales','Profit']]
tables=furniture[furniture['Sub-Category']=='Tables'][['Sub-Category','Sales','Profit']]
furnishings=furniture[furniture['Sub-Category']=='Furnishings'][['Sub-Category','Sales','Profit']]

# %% [markdown]
# ## TECHNOLOGY

# %%
phones=tech[tech['Sub-Category']=='Phones'][['Sub-Category','Sales','Profit']]
accessories=tech[tech['Sub-Category']=='Accessories'][['Sub-Category','Sales','Profit']]
machines=tech[tech['Sub-Category']=='Machines'][['Sub-Category','Sales','Profit']]
copiers=tech[tech['Sub-Category']=='Copiers'][['Sub-Category','Sales','Profit']]

# %% [markdown]
# ## OFFICE SUPPLIES

# %%
labels=office[office['Sub-Category']=='Labels'][['Sub-Category','Sales','Profit']]
storage=office[office['Sub-Category']=='Storage'][['Sub-Category','Sales','Profit']]
art=office[office['Sub-Category']=='Art'][['Sub-Category','Sales','Profit']]
binders=office[office['Sub-Category']=='Binders'][['Sub-Category','Sales','Profit']] 
appliances=office[office['Sub-Category']=='Appliances'][['Sub-Category','Sales','Profit']]
paper=office[office['Sub-Category']=='Paper'][['Sub-Category','Sales','Profit']]
envelopes=office[office['Sub-Category']=='Envelopes'][['Sub-Category','Sales','Profit']]
fasteners=office[office['Sub-Category']=='Fasteners'][['Sub-Category','Sales','Profit']]
supplies=office[office['Sub-Category']=='Supplies'][['Sub-Category','Sales','Profit']]

# %% [markdown]
# ### PROFITS OF SUBCATEGORIES

# %%
furniture.groupby(['Sub-Category'])['Profit'].mean()
# Out:
# Sub-Category
# Bookcases     -15.230509
# Chairs         43.095894
# Furnishings    13.645918
# Tables        -55.565771
# Name: Profit, dtype: float64

# %%
plt.bar(bookcases.iloc[:,0],bookcases.iloc[:,2])
plt.bar(chairs.iloc[:,0],chairs.iloc[:,2])
plt.bar(tables.iloc[:,0],tables.iloc[:,2])
plt.bar(furnishings.iloc[:,0],furnishings.iloc[:,2])
plt.grid()
plt.show()

# %%
tech.groupby(['Sub-Category'])['Profit'].mean()
# Out:
# Sub-Category
# Bookcases     -15.230509
# Chairs         43.095894
# Furnishings    13.645918
# Tables        -55.565771
# Name: Profit, dtype: float64

# %%
plt.bar(accessories.iloc[:,0],accessories.iloc[:,2])
plt.bar(copiers.iloc[:,0],copiers.iloc[:,2])
plt.bar(tables.iloc[:,0],tables.iloc[:,2])
plt.bar(machines.iloc[:,0],machines.iloc[:,2])
plt.bar(phones.iloc[:,0],phones.iloc[:,2])
plt.grid()
plt.show()

# %%
office.groupby(['Sub-Category'])['Profit'].mean()
# Out:
# Sub-Category
# Appliances    38.922758
# Art            8.200737
# Binders       19.843574
# Envelopes     27.418019
# Fasteners      4.375660
# Labels        15.236962
# Paper         24.856620
# Storage       25.152277
# Supplies      -6.258418
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10,8))
plt.bar(appliances.iloc[:,0],appliances.iloc[:,2])
plt.bar(art.iloc[:,0],art.iloc[:,2])
plt.bar(binders.iloc[:,0],binders.iloc[:,2])
plt.bar(envelopes.iloc[:,0],envelopes.iloc[:,2])
plt.bar(labels.iloc[:,0],labels.iloc[:,2])
plt.bar(storage.iloc[:,0],storage.iloc[:,2])
plt.bar(fasteners.iloc[:,0],fasteners.iloc[:,2])
plt.bar(paper.iloc[:,0],paper.iloc[:,2])
plt.bar(supplies.iloc[:,0],supplies.iloc[:,2])
plt.grid()
plt.show()

# %% [markdown]
# ## COMPARING SALES WITH PROFIT

# %%
pd.DataFrame(df.groupby(['State'])[['Sales','Profit']].mean())
# Out:
#                             Sales      Profit
# State
# Alabama                319.846557   94.865989
# Arizona                157.508933  -15.303235
# Arkansas               194.635500   66.811452
# California             228.729451   38.171608
# Colorado               176.418231  -35.867351
# Connecticut            163.223866   42.823071
# Delaware               285.948635  103.930988
# District of Columbia   286.502000  105.958930
# Florida                233.612815   -8.875461
# Georgia                266.825217   88.315453
# Idaho                  208.689810   39.367767
# Illinois               162.939230  -25.625787
# Indiana                359.431946  123.375411
# Iowa                   152.658667   39.460397
# Kansas                 121.429583   34.851813
# Kentucky               263.250000   80.573357
# Louisiana              219.453095   52.288150
# Maine                  158.816250   56.810775
# Maryland               225.766886   66.963608
# ...

# %%
plt.figure(figsize=(10,10))
plt.bar(df['State'],df['Sales'])
plt.xticks(rotation=90,fontsize=7)
plt.show()

# %%
plt.hist(df['State'])
plt.xticks(rotation=90,fontsize=7)
plt.show()

# %% [markdown]
# ## DISCOUNT AND PROFIT RELATION

# %%
plt.subplots(figsize=(6,6))
sns.lineplot(x=df['Discount'],y=df['Profit'])
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %%
sns.pairplot(df,hue='Category')

# %%
cor=df.corr()
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
##TECHNOLOGY HAS MOST SALES AND HUGE LOSS
##CONSUMERS HAS LEAST SALE AND MAXIMUM LOSS
##DISCOUNTS ARE DECREASING THE PROFIT RATIO
